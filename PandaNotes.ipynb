# %% [markdown]
# <a href="https://colab.research.google.com/github/Quinnqk/PythonClass/blob/master/PandaNotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = {"height": [10,20,40],
        "weight": [42,58,60]
}

# %%
data['height']
# Out:
# [10, 20, 40]

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    height  weight
# 0      10      42
# 1      20      58
# 2      40      60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
# height    3 non-null int64
# weight    3 non-null int64
# dtypes: int64(2)
# memory usage: 176.0 bytes

# %%
nyc_311 = pd.read_json('https://data.cityofnewyork.us/resource/erm2-nwe9.json')

# %%
nyc_311.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
# unique_key                        1000 non-null int64
# created_date                      1000 non-null object
# agency                            1000 non-null object
# agency_name                       1000 non-null object
# complaint_type                    1000 non-null object
# descriptor                        1000 non-null object
# location_type                     858 non-null object
# incident_zip                      994 non-null float64
# incident_address                  992 non-null object
# street_name                       992 non-null object
# cross_street_1                    922 non-null object
# cross_street_2                    921 non-null object
# intersection_street_1             919 non-null object
# intersection_street_2             918 non-null object
# city                              960 non-null object
# ...

# %%
nyc_311.head()
# Out:
#    unique_key             created_date  ... address_type facility_type
# 0    45522748  2020-02-02T01:59:01.000  ...          NaN           NaN
# 1    45525058  2020-02-02T01:57:36.000  ...          NaN           NaN
# 2    45525053  2020-02-02T01:57:26.000  ...          NaN           NaN
# 3    45525030  2020-02-02T01:56:50.000  ...          NaN           NaN
# 4    45524271  2020-02-02T01:56:24.000  ...          NaN           NaN
#
# [5 rows x 39 columns]

# %%
nyc_311.tail()
# Out:
#      unique_key             created_date  ... address_type facility_type
# 995    45522339  2020-02-01T21:50:10.000  ...          NaN           NaN
# 996    45522856  2020-02-01T21:50:07.000  ...          NaN           NaN
# 997    45526042  2020-02-01T21:50:05.000  ...          NaN           NaN
# 998    45526341  2020-02-01T21:49:34.000  ...      ADDRESS           NaN
# 999    45522652  2020-02-01T21:49:31.000  ...      ADDRESS           NaN
#
# [5 rows x 39 columns]

# %%
nyc_311.columns
# Out:
# Index(['unique_key', 'created_date', 'agency', 'agency_name', 'complaint_type',
#        'descriptor', 'location_type', 'incident_zip', 'incident_address',
#        'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'city', 'landmark',
#        'status', 'community_board', 'bbl', 'borough',
#        'x_coordinate_state_plane', 'y_coordinate_state_plane',
#        'open_data_channel_type', 'park_facility_name', 'park_borough',
#        'latitude', 'longitude', 'location', ':@computed_region_efsh_h5xi',
#        ':@computed_region_f5dn_yrer', ':@computed_region_yeji_bk3q',
#        ':@computed_region_92fq_4b7q', ':@computed_region_sbqj_enih',
#        'taxi_pick_up_location', 'resolution_description',
#        'resolution_action_updated_date', 'closed_date', 'address_type',
#        'facility_type'],
#       dtype='object')

# %%
nyc_311["borough"]
# Out:
# 0         QUEENS
# 1      MANHATTAN
# 2          BRONX
# 3       BROOKLYN
# 4       BROOKLYN
#          ...
# 995    MANHATTAN
# 996        BRONX
# 997        BRONX
# 998        BRONX
# 999    MANHATTAN
# Name: borough, Length: 1000, dtype: object

# %%
nyc_311[["borough","complaint_type"]]
# Out:
#        borough       complaint_type
# 0       QUEENS  Noise - Residential
# 1    MANHATTAN   Noise - Commercial
# 2        BRONX      Illegal Parking
# 3     BROOKLYN  Noise - Residential
# 4     BROOKLYN  Noise - Residential
# ..         ...                  ...
# 995  MANHATTAN  Noise - Residential
# 996      BRONX  Noise - Residential
# 997      BRONX   Noise - Commercial
# 998      BRONX       HEAT/HOT WATER
# 999  MANHATTAN       HEAT/HOT WATER
#
# [1000 rows x 2 columns]

# %%
nyc_311.describe()
# Out:
#          unique_key  ...  :@computed_region_sbqj_enih
# count  1.000000e+03  ...                   989.000000
# mean   4.552397e+07  ...                    41.462083
# std    1.747759e+03  ...                    21.583325
# min    4.552122e+07  ...                     1.000000
# 25%    4.552237e+07  ...                    25.000000
# 50%    4.552392e+07  ...                    42.000000
# 75%    4.552560e+07  ...                    62.000000
# max    4.552713e+07  ...                    77.000000
#
# [8 rows x 12 columns]

# %%
nyc_311['borough'].describe()
# Out:
# count         1000
# unique           6
# top       BROOKLYN
# freq           281
# Name: borough, dtype: object

# %%
nyc_311.iloc[2]
# Out:
# unique_key                                                                 45525053
# created_date                                                2020-02-02T01:57:26.000
# agency                                                                         NYPD
# agency_name                                         New York City Police Department
# complaint_type                                                      Illegal Parking
# descriptor                                                         Blocked Sidewalk
# location_type                                                       Street/Sidewalk
# incident_zip                                                                  10473
# incident_address                                                567 OLMSTEAD AVENUE
# street_name                                                         OLMSTEAD AVENUE
# cross_street_1                                                         CAESAR PLACE
# ...
